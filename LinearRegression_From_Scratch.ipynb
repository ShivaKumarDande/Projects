# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivaKumarDande/Projects/blob/main/LinearRegression_From_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Life Expectancy Data.csv")
#data = data.fillna(data.mean(), inplace = True) # dont use this, not getting the data when data.head() or data.tail() is used
data = data.dropna()

# %%
#finding the correlation of the data
#only values which have highest correlation with 
#life expectancy are taken into considerations
data.corr()
#Income composition of Resources and Schooling is taken into consideration.
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.050771        -0.037092
# Life expectancy                  0.050771          1.000000        -0.702523
# Adult Mortality                 -0.037092         -0.702523         1.000000
# infant deaths                    0.008029         -0.169074         0.042450
# Alcohol                         -0.113365          0.402718        -0.175535
# percentage expenditure           0.069553          0.409631        -0.237610
# Hepatitis B                      0.114897          0.199935        -0.105225
# Measles                         -0.053822         -0.068881        -0.003967
#  BMI                             0.005739          0.542042        -0.351542
# under-five deaths                0.010479         -0.192265         0.060365
# Polio                           -0.016699          0.327294        -0.199853
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   object
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   float64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   float64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
# ...

# %%
x1 = data['Income composition of resources']
x2 = data['Schooling']
y = data['Life expectancy ']

# %%
#putting the two data x1 and x2 in single vector
#so that we cando train test split
#X = np.array([x1, x2]).reshape(-1, 2);

# %%
'''import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y, y_test = train_test_split(X, y, test_size=0.00001, random_state=42)'''
# Out:
# 'import numpy as np\nfrom sklearn.model_selection import train_test_split\nX_train, X_test, y, y_test = train_test_split(X, y, test_size=0.00001, random_state=42)'

# %%
#Normalising the data (dividing with maximum value)
'''
#seperating x1 and x2 from train data
x1 = X_train[:,0]
x2 = X_train[:,1]

#x1 and x2 are train data set
x1_max = x1.max()
x1 = x1 / x1_max

x2_max = x2.max()
x2 = x2 / x2_max

#x1_test and x2_test is for test data set
x1_test = X_test[:,0]
x2_test= X_test[:,1]

x1_test = x1_test / x1_max
x2_test = x2_test / x2_max

print(x1_max)
'''

x1_max = x1.max()
x1 = x1 / x1_max

x2_max = x2.max()
x2 = x2 / x2_max

# %%
#equation is ax1 + bx2 + c = y
# a, b , c needs to be predicted, so we have 3
#differential equations
def predict(a, b, c, x1, x2):
  prediction = np.dot(a, x1) + np.dot(b, x2) + c
  return prediction

# %%
#linear regression cost function
#Cost function according to andrew ng
def costFunction(prediction, y):
  m = len(y)
  cost = np.sum(np.square(np.subtract(prediction, y)))
  cost = cost / (2 * m)
  return cost

# %%
#finding the gradient 
def gradientCalculation(prediction, x1, x2, y):
  m = len(x1)
  da = np.sum(np.multiply(np.subtract(prediction,y),x1)) / m
  db = np.sum(np.multiply(np.subtract(prediction,y),x2)) / m
  dc = np.sum(np.subtract(prediction,y)) / m
  return da, db, dc

# %%
def train(x1, x2, y, alpha, iterations):
  costs = []
  a = 0; b = 0; c = 0
  for i in range(iterations):
    prediction = predict(a, b, c, x1, x2)
    cost = costFunction(prediction, y)
    da, db, dc = gradientCalculation(prediction, x1, x2, y)
    a = a - alpha * da
    b = b - alpha * db
    c = c - alpha * dc
    costs.append(cost)

    # Print cost every at intervals 10 times or as many iterations if < 10
    if i% math.ceil(iterations/10) == 0:
      print(f"Iteration {i:4}: Cost {float(cost):8.2f}   ")
  return a, b, c, costs

# %%
a, b, c, cost = train(x1, x2, y, 1e-2, 20000)
print(f'Estimated parameters are {a}, {b}, {c}, {cost[-1]}')
# Out:
# Iteration    0: Cost  2440.07
# Iteration 2000: Cost    16.28
# Iteration 4000: Cost    16.11
# Iteration 6000: Cost    16.04
# Iteration 8000: Cost    16.01
# Iteration 10000: Cost    15.99
# Iteration 12000: Cost    15.98
# Iteration 14000: Cost    15.97
# Iteration 16000: Cost    15.96
# Iteration 18000: Cost    15.95
# Estimated parameters are 19.055204062573598, 25.011541248492154, 41.80257204411762, 15.949647109430273

# %%
#testing the alg with my inputs
test_input_X1 = 0.479
test_input_X1 = test_input_X1 / x1_max # preprocess
test_input_X2 = 10.1
test_input_X2 = test_input_X2 / x2_max # preprocess
h = predict(a, b, c, test_input_X1, test_input_X2)
print(h)
# Out:
# 63.757812309424885
